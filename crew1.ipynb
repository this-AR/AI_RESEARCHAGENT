# %% [markdown]
# # AI Research Agent Demo`n
# `n
# This notebook demonstrates the installable application. It does not run external API calls automatically.`n

# %% [markdown]
# ## 1. Install the local package`n
# `n
# Run this once in a clean notebook environment.`n

# %%
# %pip install -e .`n

# %% [markdown]
# ## 2. Configure credentials`n
# `n
# Copy `.env.example` to `.env`, then set `GROQ_API_KEY` and `GROQ_MODEL`. Do not place secrets in this notebook.`n

# %%
from ai_research_agent.config import Settings`n
`n
settings = Settings.from_env(require_live_credentials=False)`n
print(f"Search provider: {settings.search_provider}")`n
print(f"Output directory: {settings.output_dir}")`n

# %% [markdown]
# ## 3. Define a target`n

# %%
from ai_research_agent.models import ResearchTarget`n
`n
target = ResearchTarget(`n
    company_name="DeepLearning.AI",`n
    industry="Online education",`n
    key_decision_maker="Andrew Ng",`n
    position="Founder",`n
    recent_milestone="a recent AI education initiative",`n
)`n
target`n

# %% [markdown]
# ## 4. Run explicitly`n
# `n
# The next cell is intentionally commented out. Uncomment it only after configuring credentials; it makes live network and model calls.`n

# %%
# from ai_research_agent.workflow import run_research`n
# live_settings = Settings.from_env(require_live_credentials=True)`n
# result, output_path = run_research(target, live_settings)`n
# print(output_path)`n
